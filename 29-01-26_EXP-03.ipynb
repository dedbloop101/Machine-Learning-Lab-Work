# %% [markdown]
# <a href="https://colab.research.google.com/github/dedbloop101/Machine-Learning-Lab-Work/blob/main/29-01-26_EXP-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from google.colab import files
uploaded = files.upload()

df=pd.read_csv('Salary1.csv')

df.head()

df.info()
df.describe()
# Out:
#      <input type="file" id="files-17152957-fc1d-49f4-8ba4-f61743ac23bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17152957-fc1d-49f4-8ba4-f61743ac23bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sns.scatterplot(x='YearsExperience',y='Salary',data=df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from google.colab import files
uploaded = files.upload()

df=pd.read_csv('Salary2.csv')

sns.scatterplot(x='Gender',y='YearsExperience',data=df)
# Out:
#      <input type="file" id="files-6a506ff4-b150-4523-810f-b023e84dc0fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6a506ff4-b150-4523-810f-b023e84dc0fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

from google.colab import files
uploaded = files.upload()

df=pd.read_csv('Salary1.csv')

scaler=MinMaxScaler()
df[['Salary']] = scaler.fit_transform(df[['Salary']])

print(df)
# Out:
#      <input type="file" id="files-8fd56fe2-ac62-4f47-a104-db75b3b8862a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fd56fe2-ac62-4f47-a104-db75b3b8862a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
